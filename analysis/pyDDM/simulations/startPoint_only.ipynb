# %% [markdown]
# ## install & load packages

# %%
# !pip -q install git+https://github.com/mwshinn/PyDDM
import pyddm
import pyddm.plot
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pyddm import Sample
import re
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for pyddm (pyproject.toml) ... done

# %% [markdown]
# # null model: starting point offset only

# %%
def start_point(trueCongruence, bias):
  if trueCongruence == 'congruent':
    return bias
  elif trueCongruence == 'incongruent':
    return -bias
  else:
    return 0

# %%
# specify model
model = pyddm.gddm(
    starting_position = start_point,
    bound="B",
    T_dur = 4.1,
    nondecision='ndt',
    parameters={'B': (0.5, 15), 'ndt': (0.01,1.5), 'bias': (0, 1)},
    conditions = ['trueCongruence'])

pyddm.plot.model_gui_jupyter(model, data_dt=0.05, conditions={'trueCongruence':['congruent', 'incongruent', 'neutral']})
# Out:
# HBox(children=(VBox(children=(FloatSlider(value=1.9766318897125144, continuous_update=False, description='B', …
# Output()
