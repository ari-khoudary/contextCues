# %%
# !pip -q install git+https://github.com/mwshinn/PyDDM
import pyddm
import pyddm.plot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pyddm import Sample
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# simulate multiple experimental conditions
## this is annoying because i have to specify the ground truth for every single variable.. might not be worth the time
noise_durations = [[0.2, 0.5, 0.8, 1.2],
                   [0, 0.2, 0.4, 0.8],
                   [0, 0.2, 0.4, 0.8],
                   [0, 0.2, 0.4, 0.8]]
epochs = ['noise1', 'signal1', 'noise2', 'signal2']
congruence = ['congruent', 'incongruent']
nSamples = 200
all_samples = {}

for i in range(len(noise_durations)):
  for j in range(len(epochs)):
    for k in range(len(congruence)):
      key = f'sample_{i}_{j}_{k}'
      all_samples[key] = model.solve(conditions={"trueCongruence": congruence[k],
                                      'noise1': noise_durations[i][j],
                                       'signal1': noise_durations[i][j],
                                       'noise2': noise_durations[i][j],
                                       'signal2': noise_durations[i][j]}).sample(nSamples)
